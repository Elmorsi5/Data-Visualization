# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel(r"C:\Users\moham\Desktop\DataScienceCircle\sales.xlsx")

# %%
df.head()
# Out:
#    Unnamed: 0              event_id        primary_act_id  \
# 0           1  abcaf1adb99a935fc661  43f0436b905bfa7c2eec
# 1           2  6c56d7f08c95f2aa453c  1a3e9aecd0617706a794
# 2           3  c7ab4524a121f9d687d2  4b677c3f5bec71eec8d1
# 3           4  394cb493f893be9b9ed1  b1ccea01ad6ef8522796
# 4           5  55b5f67e618557929f48  91c03a34b562436efa3c
#
#        secondary_act_id   purch_party_lkup_id  \
# 0  b85143bf51323b72e53c  7dfa56dd7d5956b17587
# 1  f53529c5679ea6ca5a48  4f9e6fc637eaf7b736c2
# 2  b85143bf51323b72e53c  6c2545703bd527a7144d
# 3  b85143bf51323b72e53c  527d6b1eaffc69ddd882
# 4  b85143bf51323b72e53c  8bd62c394a35213bdf52
#
#                                           event_name  \
# 0  Xfinity Center Mansfield Premier Parking: Flor...
# 1      Gorge Camping - dave matthews band - sept 3-7
# 2        Dodge Theatre Adams Street Parking - benise
# 3  Gexa Energy Pavilion Vip Parking : kid rock wi...
# 4                      Premier Parking - motley crue
#
# ...

# %%
df.shape
# Out:
# (5000, 46)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 46 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              5000 non-null   int64
#  1   event_id                5000 non-null   object
#  2   primary_act_id          5000 non-null   object
#  3   secondary_act_id        5000 non-null   object
#  4   purch_party_lkup_id     5000 non-null   object
#  5   event_name              5000 non-null   object
#  6   primary_act_name        5000 non-null   object
#  7   secondary_act_name      1586 non-null   object
#  8   major_cat_name          5000 non-null   object
#  9   minor_cat_name          5000 non-null   object
#  10  la_event_type_cat       5000 non-null   object
#  11  event_disp_name         5000 non-null   object
#  12  ticket_text             5000 non-null   object
#  13  tickets_purchased_qty   5000 non-null   int64
# ...

# %%
df.drop_duplicates()
# Out:
#       Unnamed: 0              event_id        primary_act_id  \
# 0              1  abcaf1adb99a935fc661  43f0436b905bfa7c2eec
# 1              2  6c56d7f08c95f2aa453c  1a3e9aecd0617706a794
# 2              3  c7ab4524a121f9d687d2  4b677c3f5bec71eec8d1
# 3              4  394cb493f893be9b9ed1  b1ccea01ad6ef8522796
# 4              5  55b5f67e618557929f48  91c03a34b562436efa3c
# ...          ...                   ...                   ...
# 4995        4996  79372bc1e7e14dfd3f82  a14232befff04be1e2f3
# 4996        4997  f3b0de6a19e2a16e4fb1  83e5715f0ed3e13e6398
# 4997        4998  7c9e2f6847a2dbe4ebff  9ea8ab40f58d18305ac8
# 4998        4999  7af1ccd9a3ec3b6cef1c  e274b5c11a2a63e00141
# 4999        5000  802f4bf8026e38c2acf2  24c326bd80bd2c8c9e17
#
#           secondary_act_id   purch_party_lkup_id  \
# 0     b85143bf51323b72e53c  7dfa56dd7d5956b17587
# 1     f53529c5679ea6ca5a48  4f9e6fc637eaf7b736c2
# 2     b85143bf51323b72e53c  6c2545703bd527a7144d
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 46 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              5000 non-null   int64
#  1   event_id                5000 non-null   object
#  2   primary_act_id          5000 non-null   object
#  3   secondary_act_id        5000 non-null   object
#  4   purch_party_lkup_id     5000 non-null   object
#  5   event_name              5000 non-null   object
#  6   primary_act_name        5000 non-null   object
#  7   secondary_act_name      1586 non-null   object
#  8   major_cat_name          5000 non-null   object
#  9   minor_cat_name          5000 non-null   object
#  10  la_event_type_cat       5000 non-null   object
#  11  event_disp_name         5000 non-null   object
#  12  ticket_text             5000 non-null   object
#  13  tickets_purchased_qty   5000 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                   0
# event_id                     0
# primary_act_id               0
# secondary_act_id             0
# purch_party_lkup_id          0
# event_name                   0
# primary_act_name             0
# secondary_act_name        3414
# major_cat_name               0
# minor_cat_name               0
# la_event_type_cat            0
# event_disp_name              0
# ticket_text                  0
# tickets_purchased_qty        0
# trans_face_val_amt           0
# delivery_type_cd             0
# event_date_time              0
# event_dt                     0
# presale_dt                2892
# onsale_dt                  101
# sales_ord_create_dttm        4
# sales_ord_tran_dt            0
# print_dt                   424
# timezn_nm                    0
# venue_city                   0
# venue_state                  0
# venue_postal_cd_sgmt_1       0
# sales_platform_cd         2422
# print_flg                    0
# la_valid_tkt_event_flg       0
# ...

# %%
#we are going to get red of all those columns which have a huge number of missing values
df.drop(['secondary_act_name','presale_dt','sales_platform_cd','gndr_cd','age_yr','income_amt','edu_val','edu_1st_indv_val',
        'edu_2nd_indv_val','adults_in_hh_num','married_ind','occpn_val','occpn_1st_val','occpn_2nd_val','dist_to_ven'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              5000 non-null   int64
#  1   event_id                5000 non-null   object
#  2   primary_act_id          5000 non-null   object
#  3   secondary_act_id        5000 non-null   object
#  4   purch_party_lkup_id     5000 non-null   object
#  5   event_name              5000 non-null   object
#  6   primary_act_name        5000 non-null   object
#  7   major_cat_name          5000 non-null   object
#  8   minor_cat_name          5000 non-null   object
#  9   la_event_type_cat       5000 non-null   object
#  10  event_disp_name         5000 non-null   object
#  11  ticket_text             5000 non-null   object
#  12  tickets_purchased_qty   5000 non-null   int64
#  13  trans_face_val_amt      5000 non-null   float64
# ...

# %%
df['event_dt']
# Out:
# 0      2015-09-12
# 1      2009-09-04
# 2      2006-04-21
# 3      2011-09-02
# 4      2005-07-30
#           ...
# 4995   2008-05-22
# 4996   2015-07-16
# 4997   2008-09-26
# 4998   2006-06-24
# 4999   2016-02-19
# Name: event_dt, Length: 5000, dtype: datetime64[ns]

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                   0
# event_id                     0
# primary_act_id               0
# secondary_act_id             0
# purch_party_lkup_id          0
# event_name                   0
# primary_act_name             0
# major_cat_name               0
# minor_cat_name               0
# la_event_type_cat            0
# event_disp_name              0
# ticket_text                  0
# tickets_purchased_qty        0
# trans_face_val_amt           0
# delivery_type_cd             0
# event_date_time              0
# event_dt                     0
# onsale_dt                  101
# sales_ord_create_dttm        4
# sales_ord_tran_dt            0
# print_dt                   424
# timezn_nm                    0
# venue_city                   0
# venue_state                  0
# venue_postal_cd_sgmt_1       0
# print_flg                    0
# la_valid_tkt_event_flg       0
# fin_mkt_nm                   0
# web_session_cookie_val       0
# child_present_ind         4870
# ...

# %%
df.drop(['child_present_ind','home_owner_ind'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 29 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              5000 non-null   int64
#  1   event_id                5000 non-null   object
#  2   primary_act_id          5000 non-null   object
#  3   secondary_act_id        5000 non-null   object
#  4   purch_party_lkup_id     5000 non-null   object
#  5   event_name              5000 non-null   object
#  6   primary_act_name        5000 non-null   object
#  7   major_cat_name          5000 non-null   object
#  8   minor_cat_name          5000 non-null   object
#  9   la_event_type_cat       5000 non-null   object
#  10  event_disp_name         5000 non-null   object
#  11  ticket_text             5000 non-null   object
#  12  tickets_purchased_qty   5000 non-null   int64
#  13  trans_face_val_amt      5000 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                  0
# event_id                    0
# primary_act_id              0
# secondary_act_id            0
# purch_party_lkup_id         0
# event_name                  0
# primary_act_name            0
# major_cat_name              0
# minor_cat_name              0
# la_event_type_cat           0
# event_disp_name             0
# ticket_text                 0
# tickets_purchased_qty       0
# trans_face_val_amt          0
# delivery_type_cd            0
# event_date_time             0
# event_dt                    0
# onsale_dt                 101
# sales_ord_create_dttm       4
# sales_ord_tran_dt           0
# print_dt                  424
# timezn_nm                   0
# venue_city                  0
# venue_state                 0
# venue_postal_cd_sgmt_1      0
# print_flg                   0
# la_valid_tkt_event_flg      0
# fin_mkt_nm                  0
# web_session_cookie_val      0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4474 entries, 0 to 4999
# Data columns (total 29 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              4474 non-null   int64
#  1   event_id                4474 non-null   object
#  2   primary_act_id          4474 non-null   object
#  3   secondary_act_id        4474 non-null   object
#  4   purch_party_lkup_id     4474 non-null   object
#  5   event_name              4474 non-null   object
#  6   primary_act_name        4474 non-null   object
#  7   major_cat_name          4474 non-null   object
#  8   minor_cat_name          4474 non-null   object
#  9   la_event_type_cat       4474 non-null   object
#  10  event_disp_name         4474 non-null   object
#  11  ticket_text             4474 non-null   object
#  12  tickets_purchased_qty   4474 non-null   int64
#  13  trans_face_val_amt      4474 non-null   float64
# ...

# %%
df.head()
# Out:
#    Unnamed: 0              event_id        primary_act_id  \
# 0           1  abcaf1adb99a935fc661  43f0436b905bfa7c2eec
# 1           2  6c56d7f08c95f2aa453c  1a3e9aecd0617706a794
# 2           3  c7ab4524a121f9d687d2  4b677c3f5bec71eec8d1
# 3           4  394cb493f893be9b9ed1  b1ccea01ad6ef8522796
# 4           5  55b5f67e618557929f48  91c03a34b562436efa3c
#
#        secondary_act_id   purch_party_lkup_id  \
# 0  b85143bf51323b72e53c  7dfa56dd7d5956b17587
# 1  f53529c5679ea6ca5a48  4f9e6fc637eaf7b736c2
# 2  b85143bf51323b72e53c  6c2545703bd527a7144d
# 3  b85143bf51323b72e53c  527d6b1eaffc69ddd882
# 4  b85143bf51323b72e53c  8bd62c394a35213bdf52
#
#                                           event_name  \
# 0  Xfinity Center Mansfield Premier Parking: Flor...
# 1      Gorge Camping - dave matthews band - sept 3-7
# 2        Dodge Theatre Adams Street Parking - benise
# 3  Gexa Energy Pavilion Vip Parking : kid rock wi...
# 4                      Premier Parking - motley crue
#
# ...

# %%
df.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
df.head(20)
# Out:
#                 event_id        primary_act_id      secondary_act_id  \
# 0   abcaf1adb99a935fc661  43f0436b905bfa7c2eec  b85143bf51323b72e53c
# 1   6c56d7f08c95f2aa453c  1a3e9aecd0617706a794  f53529c5679ea6ca5a48
# 2   c7ab4524a121f9d687d2  4b677c3f5bec71eec8d1  b85143bf51323b72e53c
# 3   394cb493f893be9b9ed1  b1ccea01ad6ef8522796  b85143bf51323b72e53c
# 4   55b5f67e618557929f48  91c03a34b562436efa3c  b85143bf51323b72e53c
# 5   4f10fd8b9f550352bd56  ac4b847b3fde66f2117e  63814f3d63317f1b56c4
# 6   105ea9ee10065b54b0df  a14232befff04be1e2f3  b85143bf51323b72e53c
# 7   593b910d17913d7101cb  91c03a34b562436efa3c  b85143bf51323b72e53c
# 8   0fb4e7152e09a40ffedd  0efaba7ce3f0d7466b42  f66a1cf484a8cd868fb4
# 9   93fce8094d89e0a94aac  f6425a3223e73ea6de5a  d8c54467eb14c7dd1476
# 10  402bebb1d89c4024047a  8f53c0b7cd7810a1829d  b85143bf51323b72e53c
# 11  6adcf8b2dc8a761b22b7  094156ef72361776c8ee  b148517112c348d23c90
# 12  d3c8f5fb844690fb5af6  732d4f52a3ac2b7de8ef  b85143bf51323b72e53c
# ...

# %%
df.columns
# Out:
# Index(['event_id', 'primary_act_id', 'secondary_act_id', 'purch_party_lkup_id',
#        'event_name', 'primary_act_name', 'major_cat_name', 'minor_cat_name',
#        'la_event_type_cat', 'event_disp_name', 'ticket_text',
#        'tickets_purchased_qty', 'trans_face_val_amt', 'delivery_type_cd',
#        'event_date_time', 'event_dt', 'onsale_dt', 'sales_ord_create_dttm',
#        'sales_ord_tran_dt', 'print_dt', 'timezn_nm', 'venue_city',
#        'venue_state', 'venue_postal_cd_sgmt_1', 'print_flg',
#        'la_valid_tkt_event_flg', 'fin_mkt_nm', 'web_session_cookie_val'],
#       dtype='object')

# %%
df.loc[:,'event_date_time':'print_dt']
# Out:
#          event_date_time   event_dt  onsale_dt sales_ord_create_dttm  \
# 0    2015-09-12 23:30:00 2015-09-12 2015-05-15   2015-09-11 18:17:45
# 1    2009-09-05 01:00:00 2009-09-04 2009-03-13   2009-07-06 00:00:00
# 2    2006-04-22 01:30:00 2006-04-21 2006-02-25   2006-04-05 00:00:00
# 3    2011-09-03 00:00:00 2011-09-02 2011-04-22   2011-07-01 17:38:50
# 4    2005-07-31 01:00:00 2005-07-30 2005-03-04   2005-06-18 00:00:00
# ...                  ...        ...        ...                   ...
# 4995 2008-05-22 23:30:00 2008-05-22 2008-03-10   2008-03-10 00:00:00
# 4996 2015-07-17 05:00:00 2015-07-16 2015-04-20   2015-07-14 16:02:00
# 4997 2008-09-27 02:00:00 2008-09-26 2008-05-17   2008-05-18 00:00:00
# 4998 2006-06-25 01:00:00 2006-06-24 2006-05-06   2006-05-06 00:00:00
# 4999 2016-02-20 01:30:00 2016-02-19 2015-11-27   2016-02-18 17:11:50
#
#      sales_ord_tran_dt   print_dt
# 0           2015-09-11 2015-09-12
# 1           2009-07-05 2009-09-01
# ...

# %%
df['Event Date_print_dt'] = [d.date() for d in df['event_date_time']]
df['Event Time'] = [d.time() for d in df['event_date_time']]

# %%
df.drop(['event_date_time','print_dt'],axis=1,inplace=True)

# %%
df['sales Creation Date'] = [d.date() for d in df['sales_ord_create_dttm']]
df['sales Creation Time'] = [d.time() for d in df['sales_ord_create_dttm']]

# %%
df.drop(['sales_ord_create_dttm','sales_ord_tran_dt','event_dt','sales_ord_tran_dt'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4474 entries, 0 to 4999
# Data columns (total 27 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   event_id                4474 non-null   object
#  1   primary_act_id          4474 non-null   object
#  2   secondary_act_id        4474 non-null   object
#  3   purch_party_lkup_id     4474 non-null   object
#  4   event_name              4474 non-null   object
#  5   primary_act_name        4474 non-null   object
#  6   major_cat_name          4474 non-null   object
#  7   minor_cat_name          4474 non-null   object
#  8   la_event_type_cat       4474 non-null   object
#  9   event_disp_name         4474 non-null   object
#  10  ticket_text             4474 non-null   object
#  11  tickets_purchased_qty   4474 non-null   int64
#  12  trans_face_val_amt      4474 non-null   float64
#  13  delivery_type_cd        4474 non-null   object
# ...

# %%
df.head()
# Out:
#                event_id        primary_act_id      secondary_act_id  \
# 0  abcaf1adb99a935fc661  43f0436b905bfa7c2eec  b85143bf51323b72e53c
# 1  6c56d7f08c95f2aa453c  1a3e9aecd0617706a794  f53529c5679ea6ca5a48
# 2  c7ab4524a121f9d687d2  4b677c3f5bec71eec8d1  b85143bf51323b72e53c
# 3  394cb493f893be9b9ed1  b1ccea01ad6ef8522796  b85143bf51323b72e53c
# 4  55b5f67e618557929f48  91c03a34b562436efa3c  b85143bf51323b72e53c
#
#     purch_party_lkup_id                                         event_name  \
# 0  7dfa56dd7d5956b17587  Xfinity Center Mansfield Premier Parking: Flor...
# 1  4f9e6fc637eaf7b736c2      Gorge Camping - dave matthews band - sept 3-7
# 2  6c2545703bd527a7144d        Dodge Theatre Adams Street Parking - benise
# 3  527d6b1eaffc69ddd882  Gexa Energy Pavilion Vip Parking : kid rock wi...
# 4  8bd62c394a35213bdf52                      Premier Parking - motley crue
#
#                            primary_act_name major_cat_name minor_cat_name  \
# ...

# %%
df.columns = [col.replace('_', '') for col in df.columns]

# %%
df.head()
# Out:
#                 eventid          primaryactid        secondaryactid  \
# 0  abcaf1adb99a935fc661  43f0436b905bfa7c2eec  b85143bf51323b72e53c
# 1  6c56d7f08c95f2aa453c  1a3e9aecd0617706a794  f53529c5679ea6ca5a48
# 2  c7ab4524a121f9d687d2  4b677c3f5bec71eec8d1  b85143bf51323b72e53c
# 3  394cb493f893be9b9ed1  b1ccea01ad6ef8522796  b85143bf51323b72e53c
# 4  55b5f67e618557929f48  91c03a34b562436efa3c  b85143bf51323b72e53c
#
#        purchpartylkupid                                          eventname  \
# 0  7dfa56dd7d5956b17587  Xfinity Center Mansfield Premier Parking: Flor...
# 1  4f9e6fc637eaf7b736c2      Gorge Camping - dave matthews band - sept 3-7
# 2  6c2545703bd527a7144d        Dodge Theatre Adams Street Parking - benise
# 3  527d6b1eaffc69ddd882  Gexa Energy Pavilion Vip Parking : kid rock wi...
# 4  8bd62c394a35213bdf52                      Premier Parking - motley crue
#
#                              primaryactname majorcatname minorcatname  \
# ...
