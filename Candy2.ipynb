# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel('C:/Users/moham/Desktop/data/candyhierarchy2017.xlsx')

# %%
df.shape
# Out:
# (2460, 120)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2460 entries, 0 to 2459
# Columns: 120 entries, Internal ID to Click Coordinates (x, y)
# dtypes: float64(4), int64(1), object(115)
# memory usage: 2.3+ MB

# %%
df.info(90)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2460 entries, 0 to 2459
# Data columns (total 120 columns):
#  #   Column                                                                                 Dtype
# ---  ------                                                                                 -----
#  0   Internal ID                                                                            int64
#  1   Q1: GOING OUT?                                                                         object
#  2   Q2: GENDER                                                                             object
#  3   Q3: AGE                                                                                object
#  4   Q4: COUNTRY                                                                            object
#  5   Q5: STATE, PROVINCE, COUNTY, ETC                                                       object
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Internal ID                    0
# Q1: GOING OUT?               110
# Q2: GENDER                    41
# Q3: AGE                       84
# Q4: COUNTRY                   64
#                             ...
# Q12: MEDIA [Daily Dish]     2375
# Q12: MEDIA [Science]        1098
# Q12: MEDIA [ESPN]           2361
# Q12: MEDIA [Yahoo]          2393
# Click Coordinates (x, y)     855
# Length: 120, dtype: int64

# %%
df.drop(['Unnamed: 113', 'Click Coordinates (x, y)'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    Internal ID Q1: GOING OUT? Q2: GENDER Q3: AGE Q4: COUNTRY  \
# 0     90258773            NaN        NaN     NaN         NaN
# 1     90272821             No       Male      44        USA
# 2     90272829            NaN       Male      49         USA
# 3     90272840             No       Male      40          us
# 4     90272841             No       Male      23         usa
#
#   Q5: STATE, PROVINCE, COUNTY, ETC Q6 | 100 Grand Bar  \
# 0                              NaN                NaN
# 1                               NM                MEH
# 2                         Virginia                NaN
# 3                               or                MEH
# 4                         exton pa                JOY
#
#   Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 0                                                NaN
# 1                                            DESPAIR
# 2                                                NaN
# ...

# %%
mv = 750
df = df.loc[:, (df.isnull().sum(axis=0) <= mv)]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2460 entries, 0 to 2459
# Data columns (total 81 columns):
#  #   Column                                                                                 Non-Null Count  Dtype
# ---  ------                                                                                 --------------  -----
#  0   Internal ID                                                                            2460 non-null   int64
#  1   Q1: GOING OUT?                                                                         2350 non-null   object
#  2   Q2: GENDER                                                                             2419 non-null   object
#  3   Q3: AGE                                                                                2376 non-null   object
#  4   Q4: COUNTRY                                                                            2396 non-null   object
# ...

# %%
df.head()
# Out:
#    Internal ID Q1: GOING OUT? Q2: GENDER Q3: AGE Q4: COUNTRY  \
# 0     90258773            NaN        NaN     NaN         NaN
# 1     90272821             No       Male      44        USA
# 2     90272829            NaN       Male      49         USA
# 3     90272840             No       Male      40          us
# 4     90272841             No       Male      23         usa
#
#   Q5: STATE, PROVINCE, COUNTY, ETC Q6 | 100 Grand Bar  \
# 0                              NaN                NaN
# 1                               NM                MEH
# 2                         Virginia                NaN
# 3                               or                MEH
# 4                         exton pa                JOY
#
#   Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 0                                                NaN
# 1                                            DESPAIR
# 2                                                NaN
# ...

# %%
df.isnull().sum()
# Out:
# Internal ID                       0
# Q1: GOING OUT?                  110
# Q2: GENDER                       41
# Q3: AGE                          84
# Q4: COUNTRY                      64
#                                ...
# Q6 | Twix                       690
# Q6 | Whole Wheat anything       747
# Q6 | York Peppermint Patties    705
# Q10: DRESS                      744
# Q11: DAY                        725
# Length: 81, dtype: int64

# %%
for i in df.columns:
    df[i].fillna(df[i].mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# Internal ID                     0
# Q1: GOING OUT?                  0
# Q2: GENDER                      0
# Q3: AGE                         0
# Q4: COUNTRY                     0
#                                ..
# Q6 | Twix                       0
# Q6 | Whole Wheat anything       0
# Q6 | York Peppermint Patties    0
# Q10: DRESS                      0
# Q11: DAY                        0
# Length: 81, dtype: int64

# %%
df.head()
# Out:
#    Internal ID Q1: GOING OUT? Q2: GENDER Q3: AGE Q4: COUNTRY  \
# 0     90258773             No       Male      40         USA
# 1     90272821             No       Male      44        USA
# 2     90272829             No       Male      49         USA
# 3     90272840             No       Male      40          us
# 4     90272841             No       Male      23         usa
#
#   Q5: STATE, PROVINCE, COUNTY, ETC Q6 | 100 Grand Bar  \
# 0                       California                JOY
# 1                               NM                MEH
# 2                         Virginia                JOY
# 3                               or                MEH
# 4                         exton pa                JOY
#
#   Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 0                                            DESPAIR
# 1                                            DESPAIR
# 2                                            DESPAIR
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2460 entries, 0 to 2459
# Data columns (total 81 columns):
#  #   Column                                                                                 Non-Null Count  Dtype
# ---  ------                                                                                 --------------  -----
#  0   Internal ID                                                                            2460 non-null   int64
#  1   Q1: GOING OUT?                                                                         2460 non-null   object
#  2   Q2: GENDER                                                                             2460 non-null   object
#  3   Q3: AGE                                                                                2460 non-null   object
#  4   Q4: COUNTRY                                                                            2460 non-null   object
# ...
